# %%
import os
titles=[]
authors=[]
for path, subdirs, files in os.walk("../resources"):
    for name in files:
        filename=os.path.join(path, name)
        titles.append(filename)
        authors.append(filename[filename.index("resources\\")+10:filename.rfind("\\")])
print(", ".join(titles))
print(", ".join(authors))
# Out:
# ../resources\Alcott, Louisa May\0.txt, ../resources\Alcott, Louisa May\1.txt, ../resources\Alcott, Louisa May\10.txt, ../resources\Alcott, Louisa May\11.txt, ../resources\Alcott, Louisa May\12.txt, ../resources\Alcott, Louisa May\13.txt, ../resources\Alcott, Louisa May\14.txt, ../resources\Alcott, Louisa May\15.txt, ../resources\Alcott, Louisa May\16.txt, ../resources\Alcott, Louisa May\17.txt, ../resources\Alcott, Louisa May\18.txt, ../resources\Alcott, Louisa May\19.txt, ../resources\Alcott, Louisa May\2.txt, ../resources\Alcott, Louisa May\20.txt, ../resources\Alcott, Louisa May\21.txt, ../resources\Alcott, Louisa May\22.txt, ../resources\Alcott, Louisa May\23.txt, ../resources\Alcott, Louisa May\24.txt, ../resources\Alcott, Louisa May\25.txt, ../resources\Alcott, Louisa May\26.txt, ../resources\Alcott, Louisa May\27.txt, ../resources\Alcott, Louisa May\28.txt, ../resources\Alcott, Louisa May\29.txt, ../resources\Alcott, Louisa May\3.txt, ../resources\Alcott, Louisa May\30.txt, ../resources\Alcott, Louisa May\31.txt, ../resources\Alcott, Louisa May\32.txt, ../resources\Alcott, Louisa May\33.txt, ../resources\Alcott, Louisa May\34.txt, ../resources\Alcott, Louisa May\35.txt, ../resources\Alcott, Louisa May\36.txt, ../resources\Alcott, Louisa May\37.txt, ../resources\Alcott, Louisa May\38.txt, ../resources\Alcott, Louisa May\39.txt, ../resources\Alcott, Louisa May\4.txt, ../resources\Alcott, Louisa May\40.txt, ../resources\Alcott, Louisa May\41.txt, ../resources\Alcott, Louisa May\42.txt, ../resources\Alcott, Louisa May\5.txt, ../resources\Alcott, Louisa May\6.txt, ../resources\Alcott, Louisa May\7.txt, ../resources\Alcott, Louisa May\8.txt, ../resources\Alcott, Louisa May\9.txt, ../resources\Austen, Jane\0.txt, ../resources\Austen, Jane\1.txt, ../resources\Austen, Jane\10.txt, ../resources\Austen, Jane\11.txt, ../resources\Austen, Jane\12.txt, ../resources\Austen, Jane\13.txt, ../resources\Austen, Jane\2.txt, ../resources\Austen, Jane\3.txt, ../resources\Austen, Jane\4.txt, ../resources\Austen, Jane\5.txt, ../resources\Austen, Jane\6.txt, ../resources\Austen, Jane\7.txt, ../resources\Austen, Jane\8.txt, ../resources\Austen, Jane\9.txt, ../resources\Balzac, Honoré de\0.txt, ../resources\Balzac, Honoré de\1.txt, ../resources\Balzac, Honoré de\10.txt, ../resources\Balzac, Honoré de\100.txt, ../resources\Balzac, Honoré de\101.txt, ../resources\Balzac, Honoré de\102.txt, ../resources\Balzac, Honoré de\103.txt, ../resources\Balzac, Honoré de\104.txt, ../resources\Balzac, Honoré de\105.txt, ../resources\Balzac, Honoré de\106.txt, ../resources\Balzac, Honoré de\107.txt, ../resources\Balzac, Honoré de\108.txt, ../resources\Balzac, Honoré de\109.txt, ../resources\Balzac, Honoré de\11.txt, ../resources\Balzac, Honoré de\110.txt, ../resources\Balzac, Honoré de\111.txt, ../resources\Balzac, Honoré de\112.txt, ../resources\Balzac, Honoré de\113.txt, ../resources\Balzac, Honoré de\114.txt, ../resources\Balzac, Honoré de\115.txt, ../resources\Balzac, Honoré de\116.txt, ../resources\Balzac, Honoré de\117.txt, ../resources\Balzac, Honoré de\118.txt, ../resources\Balzac, Honoré de\119.txt, ../resources\Balzac, Honoré de\12.txt, ../resources\Balzac, Honoré de\120.txt, ../resources\Balzac, Honoré de\121.txt, ../resources\Balzac, Honoré de\122.txt, ../resources\Balzac, Honoré de\123.txt, ../resources\Balzac, Honoré de\124.txt, ../resources\Balzac, Honoré de\125.txt, ../resources\Balzac, Honoré de\13.txt, ../resources\Balzac, Honoré de\14.txt, ../resources\Balzac, Honoré de\15.txt, ../resources\Balzac, Honoré de\16.txt, ../resources\Balzac, Honoré de\17.txt, ../resources\Balzac, Honoré de\18.txt, ../resources\Balzac, Honoré de\19.txt, ../resources\Balzac, Honoré de\2.txt, ../resources\Balzac, Honoré de\20.txt, ../resources\Balzac, Honoré de\21.txt, ../resources\Balzac, Honoré de\22.txt, ../resources\Balzac, Honoré de\23.txt, ../resources\Balzac, Honoré de\24.txt, ../resources\Balzac, Honoré de\25.txt, ../resources\Balzac, Honoré de\26.txt, ../reso ...
# Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Alcott, Louisa May, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Austen, Jane, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Balzac, Honoré de, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Barrie, J. M, Baum, L. Frank, Baum, L. Frank, Baum, L. Frank, Baum, L. Fra ...

# %%
books=[open(title, encoding="utf-8", errors="ignore").read() for title in titles]
titles=[text[:text.index("~~~")] for text in books]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# %%
#max_df eliminates words that appear in >50% of the texts
#stop_words eliminates common words from inclusion in the final matrix
vectorizer = TfidfVectorizer(max_df=.5, 
                             stop_words='english')

tfidf_matrix = vectorizer.fit_transform(books)
pickle.dump(titles, open("titles.pickle", "wb"))
pickle.dump(vectorizer, open("vectorizer.pickle", "wb"))
pickle.dump(tfidf_matrix, open("tfidf_matrix.pickle", "wb"))

# %%
tfidf_matrix=pickle.load(open("tfidf_matrix.pickle", "rb"))
vectorizer=pickle.load(open("vectorizer.pickle", "rb"))
print(titles[-1])
print(tfidf_matrix[-1])
# Out:
# The Fat and the Thin
#   (0, 487823)	0.0017756641125172164
#   (0, 166724)	0.001167778104513113
#   (0, 222191)	0.0003562804924503445
#   (0, 516110)	0.00038151851324087104
#   (0, 454998)	0.000703182690242698
#   (0, 2871)	0.0007040738579649447
#   (0, 249177)	0.0003196923152449176
#   (0, 536689)	0.00038267587899445656
#   (0, 458245)	0.00040503098749852546
#   (0, 239589)	0.0004745247584330326
#   (0, 293440)	0.0006568066584549954
#   (0, 139977)	0.0014253569306280688
#   (0, 296117)	0.0023314191905213126
#   (0, 430367)	0.008699160881174318
#   (0, 330755)	0.0006372936053940961
#   (0, 182760)	0.0033079674583147045
#   (0, 297368)	0.0019345853303113728
#   (0, 121300)	0.0012078455284941876
#   (0, 366926)	0.000623468716225925
#   (0, 335082)	0.09911589482023732
#   (0, 183714)	0.0008669457816497765
#   (0, 232024)	0.00043566539195262174
#   (0, 231082)	0.0004326030789879773
#   (0, 366325)	0.0009840963117921815
#   (0, 468832)	0.0007646889344942229
#   :	:
#   (0, 378948)	0.0015593440962180162
#   (0, 139551)	0.0015593440962180162
#   (0, 264016)	0.0015593440962180162
#   (0, 435270)	0.0015593440962180162
#   (0, 435771)	0.0015593440962180162
#   (0, 152802)	0.0031186881924360325
#   (0, 367435)	0.0031186881924360325
#   (0, 326592)	0.006237376384872065
#   (0, 229818)	0.0031186881924360325
#   (0, 328105)	0.004678032288654049
#   (0, 376479)	0.004678032288654049
#   (0, 144530)	0.0015593440962180162
#   (0, 267794)	0.0015593440962180162
#   (0, 257950)	0.0015593440962180162
#   (0, 139550)	0.006237376384872065
#   (0, 22665)	0.0015593440962180162
#   (0, 45677)	0.0015593440962180162
#   (0, 106479)	0.0015593440962180162
#   (0, 106178)	0.0015593440962180162
#   (0, 276338)	0.0015593440962180162
#   (0, 69072)	0.0015593440962180162
#   (0, 42969)	0.0015593440962180162
#   (0, 445658)	0.0015593440962180162
#   (0, 31540)	0.0015593440962180162
#   (0, 437115)	0.0015593440962180162

# %%
#see most distinctive terms in each book
terms=vectorizer.get_feature_names()
top_indices=(-tfidf_matrix[:100]).toarray().argsort()[:, :5]

for index, title in enumerate(titles[:100]):
    top_terms=[terms[t] for t in top_indices[index]]
    print(f"{title}:\n{', '.join(top_terms)}\n\n")
# Out:
# The Abbot's Ghost, or Maurice Treherne's Temptation: A Christmas Story:
# treherne, snowdon, annon, jasper, octavia, maurice, mrs, blanche, tavie, major
#
#
# Aunt Jo's Scrap-Bag:
# tessa, patty, tommo, mamma, kitty, nanny, aunt, tilly, ranza, quinn
#
#
# Flower Fables:
# fairy, thistle, elves, eva, annie, lily, ripple, violet, fairies, bud
#
#
# A Garland for Girls:
# becky, ethel, jessie, jenny, henny, emily, ruth, cicely, mrs, rosy
#
#
# Hospital Sketches:
# hospital, periwinkle, mc, nurses, ward, sketches, ma, hurly, washington, sergeant
#
#
# Jack and Jill:
# jill, jack, molly, minot, frank, gus, boo, pecq, mrs, ed
#
#
# Jo's Boys:
# jo, josie, dan, ted, mrs, bhaer, nan, emil, laurie, nat
#
#
# Kitty's Class Day and Other Stories:
# amy, kipp, helen, casimer, toady, kitty, tew, hoffman, randal, psyche
#
#
# Little Men:
# bhaer, dan, nat, jo, nan, demi, tommy, daisy, mrs, teddy
#
#
# Little Men: Life at Plumfield with Jo's Boys:
# bhaer, dan, nat, jo, nan, demi, tommy, daisy, mrs, teddy
#
#
# Little Women:
# jo, laurie, meg, amy, beth, bhaer, hannah, brooke, laurence, mrs
#
#
# Little Women; Or, Meg, Jo, Beth, and Amy:
# jo, laurie, meg, amy, beth, bhaer, hannah, laurence, brooke, mrs
#
#
# Aunt Jo's Scrap-Bag VIAn Old-Fashioned Thanksgiving, Etc.:
# poppy, tilly, polly, daisy, eph, prue, lorelei, mamma, moppet, wee
#
#
# The Louisa Alcott Reader: a Supplementary Reader for the Fourth Year of School:
# effie, johnny, jocko, tommy, fay, neddy, cocky, billy, lily, mamma
#
#
# Louisa May Alcott : Her Life, Letters, and Journals:
# alcott, louisa, marmee, anna, mrs, lulu, nan, concord, boston, jo
#
#
# Lulu's Library, Volume 1:
# effie, tilda, johnny, jocko, tommy, fay, patty, neddy, cocky, billy
#
#
# Lulu's Library, Volume 2:
# betty, 16mo, bud, nelly, bonnibelle, eva, thistle, elves, lilybell, ripple
#
#
# Lulu's Library, Volume 3:
# tino, trudel, sophie, lu, lizzie, mario, aunty, tilly, di, kitty
#
#
# Marjorie's Three Gifts:
# marjorie, lizzie, belle, mamma, granny, marie, estelle, 5352, nots, billy
#
#
# May Flowers:
# almiry, maggie, anna, mamma, ella, lotty, grover, papa, lizzie, joe
#
#
# A Modern Cinderella; Or, The Little Old Shoe, and Other Stories:
# debby, nan, nelly, carroll, di, evan, laura, leavenworth, aunt, dora
#
#
# A Modern Mephistopheles and A Whisper in the Dark:
# helwyze, gladys, canaris, olivia, felix, guy, sybil, karnac, hannah, jasper
#
#
# Moods:
# sylvia, warwick, prue, moor, geoffrey, adam, ottila, yule, jessie, tilly
#
#
# Aunt Jo's Scrap-Bag, Vol. 5Jimmy's Cruise in the Pinafore, Etc.:
# gwen, jimmy, kitty, annie, hetty, rosa, jerusha, clara, pat, gus
#
#
# Mountain-Laurel and Maidenhair:
# becky, emily, maidenhair, laurel, spenser, mrs, 37807, alcott, taylor, em
#
#
# The Mysterious Key and What It Opened:
# lillian, trevlyn, hester, paul, helen, talbot, richard, mamma, maud, langdon
#
#
# An Old-Fashioned Girl:
# polly, tom, fanny, maud, trix, fan, grandma, shaw, sydney, belle
#
#
# On Picket Duty, and Other Tales:
# bopp, tew, dolly, jamie, yeou, bess, dick, bewlah, haf, waal
#
#
# Pauline's Passion and Punishment:
# pauline, manuel, gilbert, babie, redmond, mrs, 8384, tonight, dolores, alcott
#
#
# Rose in BloomA Sequel to 'Eight Cousins':
# phebe, mac, charlie, alec, steve, archie, kitty, aunt, jamie, jessie
#
#
# Rose in Bloom
# A Sequel to "Eight Cousins":
# phebe, mac, charlie, alec, steve, archie, kitty, aunt, jamie, jessie
#
#
# Shawl-StrapsA Second Series of Aunt Jo's Scrap-Bag:
# amanda, lavinia, matilda, livy, mat, pelagie, madame, gaston, shawl, jules
#
#
# Silver Pitchers: and Independence, a Centennial Love Story:
# dolly, letty, polly, portia, pris, anna, belle, ruth, nat, lennox
#
#
# Spinning-Wheel Stories:
# onawandah, abby, eli, corny, sid, orne, yvonne, daisy, tabby, geoff
#
#
# Behind a Mask; or, a Woman's Power:
# coventry, muir, jean, bella, lucia, gerald, ned, sydney, edward, dean
#
#
# Three Unpublished Poems:
# alcott, fruitlands, bronson, louisa, 28218, unpublished, poems, alcott_, microsoft, foust
#
#
# Under the Lilacs:
# ben, bab, celia, thorny, betty, sanch, lita, sancho, sam, moss
#
#
# Work: A Story of Experience:
# christie, wilkins, mrs, lisha, fletcher, letty, hepsey, ef, kitty, helen
#
#
# Bronson Alcott's Fruitlands:
# alcott, fruitlands, palmer, lane, bronson, emerson, hecker, louisa, 4to, oldham
#
#
# The Candy Country:
# tommy, billy, lily, candy, mullin, alcott, ewing, cake, louisa, gingerbread
#
#
# Comic TragediesWritten by 'Jo' and 'Meg' and Acted by The 'Little Women':
# ione, leonore, zara, norna, ion, adrian, nina, rodolpho, _enter_, hath
#
#
# Eight Cousins:
# alec, phebe, mac, archie, aunt, charlie, jessie, steve, myra, jamie
#
#
# Eight Cousins; Or, The Aunt-Hill:
# alec, phebe, mac, aunt, archie, charlie, jessie, steve, myra, jamie
#
#
# The Complete Project Gutenberg Works of Jane AustenA Linked Index of all PG Editions of Jane Austen:
# directory, index, 31100, viewer, austen, epub, downloaded, jane, mobile, htm
#
#
# Emma:
# emma, knightley, weston, elton, harriet, woodhouse, mrs, fairfax, hartfield, churchill
#
#
# Pride and Prejudice:
# darcy, bingley, elizabeth, bennet, wickham, jane, lydia, longbourn, collins, mrs
#
#
# Pride and Prejudice, a play founded on Jane Austen's novel:
# darcy, bennet, bingley, elizabeth, wickham, collins, jane, lizzy, lydia, charlotte
#
#
# Sense and Sensibility:
# elinor, marianne, dashwood, jennings, willoughby, mrs, ferrars, brandon, lucy, edward
#
#
# Sense and Sensibility:
# elinor, marianne, dashwood, jennings, willoughby, mrs, ferrars, brandon, lucy, edward
#
#
# Lady Susan:
# frederica, vernon, churchhill, susan, reginald, courcy, mainwaring, langford, mrs, james
#
#
# The Letters of Jane Austen
# Selected from the compilation of her great nephew, Edward, Lord Bradbourne:
# austen, godmersham, mrs, fanny, chawton, steventon, edward, cassandra, henry, martha
#
#
# Love and Freindship [sic]:
# freind, lesley, freindship, sophia, tho, laura, eloisa, adeiu, beleive, edward
#
#
# Mansfield Park:
# fanny, crawford, rushworth, edmund, bertram, norris, mansfield, mrs, thomas, julia
#
#
# Northanger Abbey:
# tilney, catherine, morland, thorpe, isabella, allen, eleanor, mrs, northanger, henry
#
#
# Old Friends and New Fancies: An Imaginary Sequel to the Novels of Jane Austen:
# georgiana, darcy, kitty, fitzwilliam, bingley, crawford, elizabeth, mrs, knightley, ferrars
#
#
# Persuasion:
# anne, elliot, wentworth, musgrove, harville, uppercross, kellynch, benwick, russell, mrs
#
#
# Pride and Prejudice:
# darcy, bingley, elizabeth, bennet, wickham, jane, lydia, longbourn, collins, mrs
#
#
# Adieu:
# philippe, sucy, stephanie, albon, grenadier, colonel, monsieur, beresina, countess, studzianka
#
#
# Albert Savarus:
# watteville, rodolphe, rosalie, besancon, savaron, soulas, albert, monsieur, francesca, chavoncourt
#
#
# Bureaucracy:
# rabourdin, lupeaulx, baudoyer, bixiou, dutocq, monsieur, saillard, billardiere, poiret, des
#
#
# Rise and Fall of Cesar Birotteau:
# birotteau, cesar, popinot, pillerault, cesarine, tillet, roguin, monsieur, claparon, ragon
#
#
# Sarrasine:
# sarrasine, zambinella, lanty, marianina, bouchardon, sculptor, cicognara, madame, vitagliani, arcis
#
#
# Scenes from a Courtesan's Life:
# lucien, collin, esther, peyrade, camusot, corentin, monsieur, jacques, asie, contenson
#
#
# A Second Home:
# granville, caroline, crochard, angelique, roger, bellefeuille, madame, bontems, rue, tourniquet
#
#
# The Secrets of the Princesse de Cadignan:
# arthez, cadignan, princess, espard, diane, maufrigneuse, marquise, madame, rastignac, blondet
#
#
# Seraphita:
# wilfrid, minna, seraphita, seraphitus, swedenborg, becker, fiord, monsieur, falberg, pastor
#
#
# Sons of the Soil:
# rigou, gaubertin, tonsard, aigues, soulanges, soudry, sibilet, fourchon, michaud, fayes
#
#
# A Start in Life:
# pierrotin, oscar, moreau, clapart, mistigris, georges, monsieur, serizy, leger, presles
#
#
# The Stepmother, A Drama in Five Acts:
# pauline, gertrude, godard, ferdinand, vernon, ramel, marguerite, grandchamp, madame, rimonville
#
#
# A Street of Paris and Its Inhabitant:
# marmus, adolphe, madame, rue, sinard, institute, malus, sous, trouin, duguay
#
#
# Catherine De Medici:
# christophe, catherine, guises, lecamus, medici, chaudieu, cardinal, conde, duc, calvin
#
#
# Study of a Woman:
# listomere, marquise, eugene, rastignac, madame, monsieur, marquis, 1373, caroline, joseph
#
#
# The Thirteen:
# montriveau, jules, langeais, marsay, maulincour, monsieur, paquita, armand, ferragus, henri
#
#
# The Two Brothers:
# hochon, philippe, agathe, issoudun, flore, rouget, descoings, max, bridau, joseph
#
#
# Two Poets:
# lucien, bargeton, mme, sechard, angouleme, chatelet, nais, houmeau, chardon, eve
#
#
# Unconscious Comedians:
# gazonal, bixiou, leon, vauvinet, francs, ravenouillet, lora, monsieur, massol, cousin
#
#
# The Unknown Masterpiece1845:
# porbus, poussin, frenhofer, gillette, painter, mabuse, studio, canvas, painters, color
#
#
# Ursula:
# minoret, ursula, savinien, bongrand, goupil, portenduere, massin, abbe, nemours, zelie
#
#
# Vautrin: A Drama in Five Acts:
# vautrin, lafouraille, montsorel, raoul, frescas, inez, christoval, vaudrey, duchess, duchesse
#
#
# Vendetta:
# ginevra, luigi, piombo, servin, bartolomeo, studio, roguin, corsican, thirion, laure
#
#
# El Verdugo:
# juanito, menda, leganes, verdugo, clara, chateau, marchand, victor, marquis, el
#
#
# The Celibates:
# pierrette, hochon, rogron, philippe, sylvie, agathe, flore, issoudun, rouget, descoings
#
#
# The Vicar of Tours:
# gamard, birotteau, troubert, abbe, chapeloud, mademoiselle, listomere, vicar, bourbonne, monsieur
#
#
# The Village Rector:
# graslin, veronique, montegnac, sauviat, farrabesche, madame, rector, monsieur, grossetete, tascheron
#
#
# A Woman of Thirty:
# aiglemont, julie, marquise, helene, moina, mme, vandenesse, grenville, marquis, ferdinand_
#
#
# The Works Of Balzac: A linked index to all Project Gutenberg editions:
# balzac, vie, les, le, 31565, gaudissart, verdugo, seraphita, facino, marcas
#
#
# The Works of Honoré de Balzac: About Catherine de' Medici, Seraphita, and Other Stories:
# christophe, catherine, wilfrid, cornélius, minna, guises, lecamus, seraphita, gambara, medici
#
#
# Z. Marcas:
# marcas, juste, francs, humann, zephirin, tobacco, talent, carnival, palmyra, carrel
#
#
# The Chouans:
# verneuil, hulot, francine, corentin, mademoiselle, chouans, gua, marche, fougeres, terre
#
#
# Christ in Flanders:
# flanders, skipper, hast, ostend, 1940, passengers, burgomaster, christ, cadzand, balzac
#
#
# The Collection of Antiquities:
# chesnel, croisier, esgrignon, victurnien, camusot, du, mlle, blondet, armande, mme
#
#
# Colonel Chabert:
# derville, chabert, ferraud, colonel, godeschal, boucard, monsieur, countess, delbecq, comte
#
#
# The Commission in Lunacy:
# espard, popinot, jeanrenaud, bianchon, marquise, marquis, madame, monsieur, rastignac, lavienne
#
#
# The Country Doctor:
# benassis, genestas, fosseuse, jacquotte, commandant, grenoble, butifer, napoleon, adrien, taboureau
#
#
# Cousin Betty:
# crevel, lisbeth, hulot, marneffe, valerie, hortense, wenceslas, madame, baron, adeline
#
#
# The Alkahest:
# claes, balthazar, marguerite, pierquin, lemulquinier, emmanuel, felicie, solis, monsieur, douai
#
#
# Cousin Pons:
# schmucke, cibot, pons, mme, fraisier, remonencq, poulain, marville, francs, brunner
#
#
# A Daughter of Eve:
# raoul, florine, vandenesse, nathan, tillet, countess, marie, madame, blondet, felix
#
#
# The Deputy of Arcis:
# estorade, sallenauve, monsieur, beauvisage, madame, dorlange, arcis, giguet, rastignac, bricheteau
#
#
# The Deserted Woman:
# nueil, beauseant, gaston, mme, vicomtesse, champignelles, marquise, courcelles, rodiere, valleroy

# %%
#create clusters of texts
# from sklearn.cluster import KMeans
# from collections import defaultdict

# kmeans=KMeans(n_clusters=12)
# labels=kmeans.fit_predict(tfidf_matrix)

# clustering=defaultdict(list)
# for title, label in zip(titles, labels):
#     clustering[label].append(title)
# for cluster, elements in sorted(clustering.items()):
#     print(f"Cluster {label}: {', '.join(elements)}")

# %%
#get the cosine similarities per text
from sklearn.metrics.pairwise import linear_kernel
import collections
from nltk.tokenize import word_tokenize
with open("../userChosenText.txt", "r", encoding="utf-8", errors="ignore") as user_text:
#     user_text=user_text.read().lower()
#     user_text=word_tokenize(user_text)
#     user_bow=collections.Counter(user_text).items()
v=vectorizer.vocabulary_
new_vectorizer=TfidfVectorizer(stop_words="english", vocabulary=v)
user_tfidf=new_vectorizer.fit_transform(user_text)
print(user_tfidf)
# cosine_similarities = linear_kernel(tfidf_matrix[-1:], tfidf_matrix).flatten()
# related_text_indices = cosine_similarities.argsort()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-83b9f7f7747f> in <module>()
#       9 v=vectorizer.vocabulary_
#      10 new_vectorizer=TfidfVectorizer(stop_words="english", vocabulary=v)
# ---> 11 user_tfidf=new_vectorizer.fit_transform(user_bow)
#      12 print(user_tfidf)
#      13 # cosine_similarities = linear_kernel(tfidf_matrix[-1:], tfidf_matrix).flatten()
#
# c:\users\anlan\appdata\local\programs\python\python36\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1379             Tf-idf-weighted document-term matrix.
#    1380         """
# -> 1381         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1382         self._tfidf.fit(X)
#    1383         # X is already a transformed view of raw_documents so
#
# c:\users\anlan\appdata\local\programs\python\python36\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#     867
#     868         vocabulary, X = self._count_vocab(raw_documents,
# --> 869                                           self.fixed_vocabulary_)
#     870
#     871         if self.binary:
#
# c:\users\anlan\appdata\local\programs\python\python36\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     790         for doc in raw_documents:
#     791             feature_counter = {}
# --> 792             for feature in analyze(doc):
#     793                 try:
#     794                     feature_idx = vocabulary[feature]
#
# c:\users\anlan\appdata\local\programs\python\python36\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(doc)
#     264
#     265             return lambda doc: self._word_ngrams(
# --> 266                 tokenize(preprocess(self.decode(doc))), stop_words)
#     267
#     268         else:
#
# c:\users\anlan\appdata\local\programs\python\python36\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(x)
#     230
#     231         if self.lowercase:
# --> 232             return lambda x: strip_accents(x.lower())
#     233         else:
#     234             return strip_accents
#
# AttributeError: 'tuple' object has no attribute 'lower'

# %%
related_text_titles = [titles[int(i)] for i in related_text_indices]
related_text_titles=related_text_titles[0:-1]
print(related_text_titles)
# Out:
# ['Et dukkehjem. English by Henrik Ibsen', 'The Tale of Peter Rabbit by Beatrix Potter', 'Hedda Gabler by Henrik Ibsen', 'The Importance of Being Earnest: A Trivial Comedy for Serious People by Oscar Wilde', 'Metamorphosis by Franz Kafka', 'Sense and Sensibility by Jane Austen', 'Pygmalion by Bernard Shaw', 'Emma by Jane Austen', 'Anne of Green Gables by L. M.  Montgomery', 'Ethan Frome by Edith Wharton', "Alice's Adventures in Wonderland by Lewis Carroll", 'A Christmas Carol in Prose; Being a Ghost Story of Christmas by Charles Dickens', 'Pride and Prejudice by Jane Austen', 'Persuasion by Jane Austen', 'The Mysterious Affair at Styles by Agatha Christie', 'Mansfield Park by Jane Austen', 'Peter Pan by J. M.  Barrie', 'The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson', 'The Wonderful Wizard of Oz by L. Frank  Baum', 'Little Women by Louisa May Alcott', 'The Strange Case of Dr. Jekyll and Mr. Hyde by Robert Louis Stevenson', 'Great Expectations by Charles Dickens', 'My Secret Life, Volumes I. to III. by Anonymous', 'Hard Times by Charles Dickens', 'Adventures of Huckleberry Finn by Mark Twain', 'Siddhartha by Hermann Hesse', 'The Adventures of Tom Sawyer by Mark Twain', 'Wuthering Heights by Emily Brontë', 'The Hound of the Baskervilles by Arthur Conan Doyle', 'Forbidden Fruit by Anonymous', 'The Call of the Wild by Jack London', 'An Occurrence at Owl Creek Bridge by Ambrose Bierce', 'The Awakening, and Selected Short Stories by Kate Chopin', 'The Adventures of Sherlock Holmes by Arthur Conan Doyle', 'The Romance of Lust: A Classic Victorian erotic novel by Anonymous', 'The Yellow Wallpaper by Charlotte Perkins Gilman', 'Prestuplenie i nakazanie. English by Fyodor Dostoyevsky', 'Treasure Island by Robert Louis Stevenson', 'Oliver Twist by Charles Dickens', 'The Divine Comedy by Dante, Illustrated by Dante Alighieri', 'Anna Karenina by graf Leo Tolstoy', 'The Picture of Dorian Gray by Oscar Wilde', 'The Count of Monte Cristo, Illustrated by Alexandre Dumas', 'A Tale of Two Cities by Charles Dickens', 'The Turn of the Screw by Henry James', 'The Legend of Sleepy Hollow by Washington Irving', 'Manifest der Kommunistischen Partei. English by Friedrich Engels and Karl Marx', 'Dracula by Bram Stoker', 'A Study in Scarlet by Arthur Conan Doyle', 'The Time Machine by H. G.  Wells', 'On the origin of species by Charles Darwin', 'Dubliners by James Joyce', "Uncle Tom's Cabin by Harriet Beecher Stowe", 'A Modest Proposal by Jonathan Swift', 'The Drawings of Leonardo da Vinci by da Vinci Leonardo', 'The Kama Sutra of Vatsyayana by Vatsyayana', 'Autobiography of Benjamin Franklin by Benjamin Franklin', 'Beowulf: An Anglo-Saxon Epic Poem', 'Jane Eyre: An Autobiography by Charlotte Brontë', 'Heart of Darkness by Joseph Conrad', "Grimms' Fairy Tales by Jacob Grimm and Wilhelm Grimm", 'The Tragical History of Doctor Faustus by Christopher Marlowe', 'War and Peace by graf Leo Tolstoy', "Gulliver's Travels into Several Remote Nations of the World by Jonathan Swift", 'Les Misérables by Victor Hugo', '1000 Things Worth Knowing by Nathaniel C. Fowler', 'Second Treatise of Government by John Locke', 'Don Quixote by Miguel de Cervantes Saavedra', 'The Federalist Papers by Alexander Hamilton and John Jay and James Madison', 'Moby Dick; Or, The Whale by Herman Melville', 'Notes from the Underground by Fyodor Dostoyevsky', 'The Life and Adventures of Robinson Crusoe by Daniel Defoe', 'Il Principe. English by Niccolò Machiavelli', 'The Tragedy of Romeo and Juliet by William Shakespeare', 'The Elements of Style by William Strunk', 'Candide by Voltaire', 'Songs of Innocence, and Songs of Experience by William Blake', 'Ulysses by James Joyce', 'Frankenstein; Or, The Modern Prometheus by Mary Wollstonecraft Shelley', 'The Souls of Black Folk by W. E. B.  Du Bois', 'Narrative of the Life of Frederick Douglass, an American Slave by Frederick Douglass', 'Democracy in America — Volume 1 by Alexis de Tocqueville', 'Leviathan by Thomas Hobbes', ...

# %%
import csv
with open('../book_tfidf_closeness.csv', 'w+', encoding="utf-8", errors="ignore") as csv_file:
    writer = csv.writer(csv_file)
    for i, title in enumerate(related_text_titles):
        writer.writerow([title, len(related_text_titles)-i])
